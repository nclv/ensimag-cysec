# %% [markdown]
# # Differential Power Analysis
#
# Contrary to previous lab on leakage assessment where we had control over the key value, this session's goal is to retrieve an unknown key, used during an AES encryption. The attacker can send randomly chosen plaintexts and records power consumption.
#
# The first -- and quick -- part will consist in collecting traces. The second part wil introduce DPA, implement this attack and retrieve the key. The last part will give further insight into this type of attacks.

# %% [markdown]
# ## Acquisitions
# 1. Communicate with the chip
# 2. Get a trace on the scope / Power analysis on AES
# 3. Get a set of (traces/plaintexts) to be attacked later

# %%
import os
import numpy as np
import matplotlib.pyplot as plt 
import serial
import time

from tqdm import tnrange
import tqdm

# %%
# Install a Crypto package in the current python kernel
import sys
# !{sys.executable} -m pip install Crypto
from Crypto.Cipher import AES
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Crypto in /home/nicolas/.local/lib/python3.9/site-packages (1.4.1)
# Requirement already satisfied: shellescape in /home/nicolas/.local/lib/python3.9/site-packages (from Crypto) (3.8.1)
# Requirement already satisfied: Naked in /home/nicolas/.local/lib/python3.9/site-packages (from Crypto) (0.1.31)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from Naked->Crypto) (2.25.1)
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from Naked->Crypto) (5.3.1)
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# connection to the chip / set up chip specific parameters
SCOPETYPE='OPENADC'
PLATFORM='CWLITEARM'
CRYPTO_TARGET='TINYAES128C' 
#CW_PATH = '../chipwhisperer/'
CW_PATH = '/home/vagrant/work/projects/chipwhisperer/'

setup_script = CW_PATH  + "jupyter/Setup_Scripts/Setup_Generic.ipynb"
# %run $setup_script
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/lib/python3/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     702             fpath = arg_lst[0]
# --> 703             filename = file_finder(fpath)
#     704         except IndexError:
#
# /usr/lib/python3/dist-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'/home/vagrant/work/projects/chipwhisperer/jupyter/Setup_Scripts/Setup_Generic.ipynb.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-3-6708981c9e6f> in <module>
#       7
#       8 setup_script = CW_PATH  + "jupyter/Setup_Scripts/Setup_Generic.ipynb"
# ----> 9 get_ipython().run_line_magic('run', '$setup_script')
#
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2334                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2335             with self.builtin_trap:
# -> 2336                 result = fn(*args, **kwargs)
#    2337             return result
#    2338
#
# <decorator-gen-52> in run(self, parameter_s, runner, file_finder)
#
# /usr/lib/python3/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/lib/python3/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     712             if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     713                 warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 714             raise Exception(msg)
#     715         except TypeError:
#     716             if fpath in sys.meta_path:
#
# Exception: File `'/home/vagrant/work/projects/chipwhisperer/jupyter/Setup_Scripts/Setup_Generic.ipynb.py'` not found.

# %% [markdown]
# Next: Program the target with th AES software, identical to the leakage assessment lab (TP2).

# %%
# program target with software AES
cw.program_target(scope, prog, "./simpleserial-aes-{}.hex".format(PLATFORM))

# %% [markdown]
# ### Chip communication
# #### Firmware commands
# The firmware consists in a simple AES-128 ciphering. There are 3 commands in the firmware:
# 1. `k` command + 16 bytes => set the key to this specific value 16 bytes.
# 2. `p` command + 16 bytes => cipher the 16-byte message/plaintext with the key defined above.
# 3. `g` command + 16 bytes => cipher the 16-byte message/plaintext with an **uknown key**. This is the key you should retrieve.
#
# The following functions are defined and self-explicit.

# %%
def send_key(key):
    assert type(key) is np.ndarray, "Key must be array Numpy"
    #assert all([type(octet) is np.uint8 for octet in key]), "Key must be a vector of bytes"
    assert np.shape(key) == (16,), "key length must be 16 bytes"
    assert all([0 <= octet <= 255 for octet in key]), "The value of each key byte must be between 0 and 255"
    
    target.simpleserial_write('k', bytearray(key))
    time.sleep(0.01)

def cipher(plain):
    assert type(plain) is np.ndarray, "Plaintext must be array Numpy"
    assert all([type(octet) is np.uint8 for octet in plain]), "Plaintext must be a vector of bytes"
    assert np.shape(plain) == (16,), "Plaintext length must be 16 bytes"
    assert all([0 <= octet <= 255 for octet in plain]), "The value of each input byte must be between 0 and 255"
    
    target.simpleserial_write('p', bytearray(plain))
    time.sleep(0.01)
    chiffre = target.simpleserial_read_witherrors('r', 16)
    return chiffre

def secret_cipher(plain):
    assert type(plain) is np.ndarray, "Plaintext must be array Numpy"
    assert all([type(octet) is np.uint8 for octet in plain]), "Plaintext must be a vector of bytes"
    assert np.shape(plain) == (16,), "Plaintext length must be 16 bytes"
    assert all([0 <= octet <= 255 for octet in plain]), "The value of each input byte must be between 0 and 255"
    
    target.simpleserial_write('g', bytearray(plain))
    time.altzonesleep(0.01)
    chiffre = target.simpleserial_read_witherrors('r', 16)
    
    return chiffre

# %% [markdown]
# ### Questions:
# 1. Check with a random key and plaintext that the ciphering function is correct.

# %%
key = np.random.randint(low=0, high=256, size=16, dtype=np.uint8) 
plaintext = np.random.randint(low=0, high=256, size=16, dtype=np.uint8) 

cipher_python = AES.new(key.tobytes(),  AES.MODE_ECB).encrypt(plaintext.tobytes())

send_key(key)
cipher_chip = cipher(plaintext)

assert bytes(cipher_python).hex() == cipher_chip["payload"].hex()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-de3ae3b2edc7> in <module>
#       4 cipher_python = AES.new(key.tobytes(),  AES.MODE_ECB).encrypt(plaintext.tobytes())
#       5
# ----> 6 send_key(key)
#       7 cipher_chip = cipher(plaintext)
#       8
#
# NameError: name 'send_key' is not defined

# %% [markdown]
# 2. Show that the key is different - and unknown - when the `secret_cipher` function is used (`g` command).

# %%
response = secret_cipher(plaintext) ##
print("Chip:  " , response["payload"].hex()) ##

assert bytes(cipher_python).hex() != response["payload"].hex()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-cd6d56418dc1> in <module>
# ----> 1 response = secret_cipher(plaintext) ##
#       2 print("Chip:  " , response["payload"].hex()) ##
#       3
#       4 assert bytes(cipher_python).hex() != response["payload"].hex()
#
# NameError: name 'secret_cipher' is not defined

# %% [markdown]
# ### Scope
# #### Goal:
#
# We already identify the 10 AES-128 rounds in the previous lab. In this DPA attack, we will target only the first round. The goal of this section is to record 2500 traces with its corresponding plaintext.

# %%
# print scope parameters
scope
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b85504e848da> in <module>
#       1 # print scope parameters
# ----> 2 scope
#
# NameError: name 'scope' is not defined

# %%
print("Number of samples to be recorded: " + str(scope.adc.samples))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-115beab6bebe> in <module>
# ----> 1 print("Number of samples to be recorded: " + str(scope.adc.samples))
#
# NameError: name 'scope' is not defined

# %% [markdown]
# 1. Plot all the AES rounds

# %%
# scope.adc.decimate: The ADC downsampling factor.
# This value instructs the ChipWhisperer to only record 1 sample in every <decimate>. In other words, 
# if this value is set to 10, the sampling rate is set to 1/10th of the sampling clock.
# This setting is helpful for recording very long operations or for reducing the sampling rate for streaming mode.

scope.adc.samples = 2500
scope.adc.decimate = 12
# arm the scope to be ready for acquistions
scope.arm()
# the command 'p' includes a signal at the beginning of AES encryption that is sent to the scope to begin acquisition
secret_cipher(plaintext)
ret = scope.capture()
wave = scope.get_last_trace()
plt.plot(wave)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-4d6082230aab> in <module>
#       4 # This setting is helpful for recording very long operations or for reducing the sampling rate for streaming mode.
#       5
# ----> 6 scope.adc.samples = 2500
#       7 scope.adc.decimate = 12
#       8 # arm the scope to be ready for acquistions
#
# NameError: name 'scope' is not defined

# %% [markdown]
# 2. Plot only the first round

# %%
scope.adc.samples = 3500
scope.adc.decimate = 1
# arm the scope to be ready for acquistions
scope.arm()
# the command 'p' includes a signal at the beginning of AES encryption that is sent to the scope to begin acquisition
secret_cipher(plaintext)
ret = scope.capture()
wave = scope.get_last_trace()
plt.plot(wave)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-0413a9daa6eb> in <module>
# ----> 1 scope.adc.samples = 3500
#       2 scope.adc.decimate = 1
#       3 # arm the scope to be ready for acquistions
#       4 scope.arm()
#       5 # the command 'p' includes a signal at the beginning of AES encryption that is sent to the scope to begin acquisition
#
# NameError: name 'scope' is not defined

# %% [markdown]
# #### Acquistion of traces/plaintexts
#  -  acquire 2000 sets of (trace/plaintext). The function `acquire_traces` is already written.

# %%
def acquire_traces(count=10):
    '''probe : array [scope, channel]
    count: number of curves to save
    returns plaintexts, trace
    '''    
    plaintexts = []
    traces = np.zeros((count, scope.adc.samples), dtype=np.float)

    for i in tnrange(count, desc = "Capturing"):
        plaintext = np.random.randint(low=0, high=256, size=16, dtype=np.uint8)
        plaintexts.append(plaintext)
        scope.arm()

        secret_cipher(plaintext)
        ret = scope.capture()
        if ret:
            print("Target timed out!")
            continue
        else:
            trace = scope.get_last_trace()
            traces[i] = trace
            
        #scope.stop()
    return traces, plaintexts

tr,pl = acquire_traces(2000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-aafdfcfb9833> in <module>
#      24     return traces, plaintexts
#      25
# ---> 26 tr,pl = acquire_traces(2000)
#
# <ipython-input-10-aafdfcfb9833> in acquire_traces(count)
#       5     '''
#       6     plaintexts = []
# ----> 7     traces = np.zeros((count, scope.adc.samples), dtype=np.float)
#       8
#       9     for i in tnrange(count, desc = "Capturing"):
#
# NameError: name 'scope' is not defined

# %%
import os
dir_name = "acqui/"
try:
    os.mkdir(dir_name)
    np.save(dir_name + './tracesAES', tr)
    np.save(dir_name + '/plaintexts', pl)
    print("New files correctly saved")
except:
    # in order to avoid erasing traces
    print("Directory already created, delete it before saving new files.")
# Out:
# Directory already created, delete it before saving new files.

# %%
# AES SBOX as an array
SBOX = np.array([
    ], dtype=np.int)

# %% [markdown]
# In case you lose or modify the variables traces / plaintexts, you can retrieve them by executing the following cell. It recovers all data by reading the saved files.

# %%
# load traces
traces_exp = np.load("./acqui/tracesAES.npy")
plaintexts_exp = np.load("./acqui/plaintexts.npy")

#traces_simu = np.load("./simu/traces_simu.npy")
#plaintexts_simu  = np.load("./simu/plaintexts.npy")

# %% [markdown]
# You can check if the traces are correct when plotting few curves.

# %%
plt.figure()
plt.plot(traces_exp[:5].T)
plt.show()

# %% [markdown]
# You can also have a look at the first plaintexts.

# %%
print(plaintexts_exp[:5])
# Out:
# [[162  57  16  68 195  82  55 198 205 215 167 189 206  10  37 129]
#  [ 12 150 177  79 147  93  37 150  10 202 233 111 142  53 220 140]
#  [204 183  90  91  83   2  89 140  87 174  23  93  24 251 108 223]
#  [114  72   6 189   6 175  80 238  35  51 190 252  90  29 215   6]
#  [177  90  39 174 231  41 200 158  60 167  59 181 134  22 223  45]]

# %% [markdown]
# ### Choose the dataset: simulation or experimental
#
# In order to quickly debug, we advise to first use the simulation sets (`traces_simu` and `plaintexts_simu`). The number of curves ands samples are smaller in this set. When all the DPA attack is validated for this set, you can switch to the real-experimental traces to retrieve the key by modifying the following cell.

# %%
#traces = traces_simu
#messages = plaintexts_simu
traces = traces_exp
messages = plaintexts_exp

# %% [markdown]
# ### Target + Leakage model : Selection function
# - the selection function aka target function is a function which depends on a secret (a key for instance) and a known value (message/plaintext/ciphertext).
# - first write the target function: `byte_i` output of first SBOX
# - second write the DPA simple leakage model: from a byte chos
# - write a typical selection function for DPA, which shall return (0,1) and depends $j^{th}$ bit (`bit_j`) output of an AES state (`byte_i`) after the first SubBytes and then choose the position.

# %% [markdown]
# ## DPA attacks
#
# The attack will target the values after the first SBox, which depends on the plaintext and the key. These values shall be separated into 2 parts, hence the Differential name of this attack, by a predefined `selection` function. In our case, we will select 1 bit of this value. This is the bit where the physical leakage is expected.
#
# There are 16 different byte position in an AES state so we will need 16 independant DPA attack to recover the whole key.
# ![selection_target.PNG](attachment:selection_target.PNG)

# %% [markdown]
# ### Questions
# 1. Determine the `target` function which calculate the intermediate value for a given plaintext, key and byte position

# %%
# returns the output values after the first SBOX 
def target_function(msg, key, byte_i):
    ''' msg: 16 byte AES plaintext
        key: 16 bytes AES key
        byte_i:  byte position
        returns: 1 byte at the output of first SBOX
    '''
    return SBOX[msg ^ key][byte_i]

def test_target_function():
    key = np.random.randint(low=0, high=256, size=16, dtype=np.uint8) 
    plaintext = np.random.randint(low=0, high=256, size=16, dtype=np.uint8) 
    for i in range(16):
        print(target_function(plaintext, key, i), end=", ")
        
test_target_function()
# Out:
# 83, 151, 93, 201, 86, 96, 159, 166, 248, 242, 35, 50, 32, 232, 81, 102,

# %% [markdown]
# 2. Determine the `selection` function, which returns (0,1) the value of `bit_j` of the target function with `byte_i`. You can use an intermediate leakage function which is already written.
# 3. The selection function we will use in the attack is `sel_0` which target the first bit.

# %%
# returns the value of bit_j of a byte
def leakage_function(byte_i, bit_j):
    ''' byte: 
        bit: 
        returns: 0/1 
    '''
    return (byte_i >> bit_j) & 1  

def selection(msg, key, byte_i, bit_j):
    ''' mess: message/plaintext
     key : key
     byte_n : the targeted byte
     bit_n : the targeted bit in the byte
     returns 0/1 
    '''
    return leakage_function(target_function(msg, key, byte_i), bit_j)

# sel0 is selection  with bit_j = 0 
# this function will be used fo further attacks
def sel0(msg, key, byte_i):
    return selection(msg, key, byte_i, 0)


def test_selection_bit_j_equal_zero():
    key = np.random.randint(low=0, high=256, size=16, dtype=np.uint8) 
    plaintext = np.random.randint(low=0, high=256, size=16, dtype=np.uint8) 
    for i in range(16):
        print(f"Target function : {target_function(plaintext, key, i)}, sel0 : {sel0(plaintext, key, i)}")
        assert target_function(plaintext, key, i) % 2 == sel0(plaintext, key, i)  # correspond to the parity of the byte
        
test_selection_bit_j_equal_zero()
# Out:
# Target function : 242, sel0 : 0
# Target function : 185, sel0 : 1
# Target function : 178, sel0 : 0
# Target function : 147, sel0 : 1
# Target function : 220, sel0 : 0
# Target function : 178, sel0 : 0
# Target function : 193, sel0 : 1
# Target function : 224, sel0 : 0
# Target function : 226, sel0 : 0
# Target function : 120, sel0 : 0
# Target function : 248, sel0 : 0
# Target function : 145, sel0 : 1
# Target function : 15, sel0 : 1
# Target function : 189, sel0 : 1
# Target function : 254, sel0 : 0
# Target function : 184, sel0 : 0

# %% [markdown]
# ### Attack
#
#
# Knowing the plaintext, if you guess a byte of the key, you can determine the value of the selection function and choose in which set the trace is.  If this is the correct key, there will a statistical difference between the 2 sets, that you can calculate.
# ![selection_function.PNG](attachment:selection_function.PNG)

# %% [markdown]
# You can calculate this `hypothesis` trace (in red on the Figure) for every key guess. The higher value of this `hypothesis` will correspond the more likely key.

# %% [markdown]
# The whole algorithm ro recover a byte of the key - already seen during the lectures, can be summarized below:
#
# ```
#     For each key_guess (among 256 possibilities):
#         For each (trace, plaintext)
#             Compute selection_function(key_guess, plaintext)
#             Store the trace in the correct set according to selection_output
#         Compute the differential trace of the 2 sets
# ```
# Take care that the 2 sets will not have same cardinal (number of elements) so be sure to normalize the 2 sets by the number of elements.
#
# We find the guess which has the highest peak => most likely key

# %% [markdown]
# ### Questions:
# 1. For a key `guess`, construct the `hypothesis` vector for every couple (`traces`, `messages`).

# %%
def hypothesis(guess, messages, traces, selection_function):
    '''
    guess: key for this hypothesis
    messages: vector of n values 
    traces: matrix of traces (n . t)
    selection_function: a funtion which takes (m, k) as inputs and returns (0,1). You can use a lambda function derived from 
        the sel0 function
    returns hypothesis(vector)
    '''
    h_0 = np.zeros(len(traces[0]), dtype = np.float64)
    h_1 = np.zeros(len(traces[0]), dtype = np.float64)
    
    h_0_count = 0
    h_1_count = 0
    for trace, message in zip(traces, messages):
        bit = selection_function(message, guess)
        if bit:
            h_1 += trace
            h_1_count += 1
        else:
            h_0 += trace
            h_0_count += 1
    
    if h_0_count == 0:
        mean_0 = 0
    else:
        mean_0 = (h_0 / h_0_count)
        
    if h_1_count == 0:
        mean_1 = 0
    else:
        mean_1 = (h_1 / h_1_count)
    
    # return the difference of the two sets ie. abs(mean(h_0) - mean(h_1))
    return np.abs(mean_0 - mean_1)

def test_hypothesis(messages, traces):
    key_guess = np.random.randint(low=0, high=256, size=16, dtype=np.uint8) 
    hypothesis_vector = hypothesis(key_guess, messages, traces, lambda m, g: sel0(m, g,  0))
    print(hypothesis_vector.shape, hypothesis_vector[:10])

test_hypothesis(messages, traces)
# Out:
# (3500,) [2.62894831e-06 2.64230790e-04 9.28335166e-05 1.16369049e-04
#  8.30794543e-05 1.74436385e-04 2.46761761e-05 5.95790783e-05
#  7.19659952e-05 2.27437233e-04]

# %% [markdown]
# 2. Plot this hypothesis vector for simulated traces and key guess 0, on byte 0 and compare with key guess 0xC1. Comment the result.

# %%
guess = 0xC1
res = hypothesis(guess, messages, traces, lambda m, g: sel0(m, g,  0))

plt.plot(res, label = str(guess))

guess = 0x00
res = hypothesis(guess, messages, traces, lambda m, g: sel0(m, g,  0))

plt.plot(res, label = str(guess))
plt.legend()
plt.show()

# The guess 0xc1 appears to be the first byte of the key

# %% [markdown]
# 3. Construct the resulting matrix h for every key guesses and plot it.

# %%
def dpa(guesses, messages, traces, selection_function):
    matrix = np.zeros((256, len(traces[0])), dtype = np.float64)
    
    for index, key_guess in enumerate(guesses):
        matrix[index] = hypothesis(key_guess, messages, traces, selection_function)
    
    return matrix  # matrix of 256 hypothesis vectors

# %%
plt.figure()
plt.plot(dpa(range(0, 256), messages, traces, lambda m, g: sel0(m, g,  0)))
plt.show()

# %% [markdown]
# 4. Determine a criteria to find the correct key byte 0 and find this first key byte.

# %%
# correct_key returns the indexes of the max in dpa_out
correct_key = lambda dpa_out: np.unravel_index(np.argmax(dpa_out, axis=None), dpa_out.shape)

dpa_out = dpa(range(0, 256), messages, traces, lambda m, g: sel0(m, g,  0))
indexes = correct_key(dpa_out)
print(f"Indexes : {indexes}, Maximum value : {dpa_out[indexes]}")
# Out:
# Indexes : (193, 1309), Maximum value : 0.006183767250534773

# %% [markdown]
# 5. Retrieve every key byte and find the final key.

# %%
key_list = []
#to_plot = []
time_pos = []
#nb_traces = 1000

for pos in range(16):
    key_byte, time = correct_key(dpa(range(0, 256), messages, traces, lambda m, g: sel0(m, g,  pos)))
    key_list.append(key_byte)
    time_pos.append(time)
    print("key_"+ str(pos) + " = " + str(bytearray(key_list)))
# Out:
# key_0 = bytearray(b'\xc1')
# key_1 = bytearray(b'\xc1^')
# key_2 = bytearray(b'\xc1^\xc0')
# key_3 = bytearray(b'\xc1^\xc0\x15')
# key_4 = bytearray(b'\xc1^\xc0\x15\xde')
# key_5 = bytearray(b'\xc1^\xc0\x15\xde\xc0')
# key_6 = bytearray(b'\xc1^\xc0\x15\xde\xc0\xde')
# key_7 = bytearray(b'\xc1^\xc0\x15\xde\xc0\xde\xd0')
# key_8 = bytearray(b'\xc1^\xc0\x15\xde\xc0\xde\xd0\xca')
# key_9 = bytearray(b'\xc1^\xc0\x15\xde\xc0\xde\xd0\xca\xfe')
# key_10 = bytearray(b'\xc1^\xc0\x15\xde\xc0\xde\xd0\xca\xfe\xde')
# key_11 = bytearray(b'\xc1^\xc0\x15\xde\xc0\xde\xd0\xca\xfe\xde\xad')
# key_12 = bytearray(b'\xc1^\xc0\x15\xde\xc0\xde\xd0\xca\xfe\xde\xad\xbe')
# key_13 = bytearray(b'\xc1^\xc0\x15\xde\xc0\xde\xd0\xca\xfe\xde\xad\xbe\xef')
# key_14 = bytearray(b'\xc1^\xc0\x15\xde\xc0\xde\xd0\xca\xfe\xde\xad\xbe\xef\x00')
# key_15 = bytearray(b'\xc1^\xc0\x15\xde\xc0\xde\xd0\xca\xfe\xde\xad\xbe\xef\x00\xff')

# %%
key = bytearray(key_list).hex()
print(f"Key : {key}")
print(f"Time positions : {time_pos}")
# Out:
# Key : c15ec015dec0ded0cafedeadbeef00ff
# Time positions : [1309, 1485, 1661, 1837, 1345, 2041, 1701, 2121, 1389, 2049, 2073, 2113, 1425, 2057, 1985, 2105]

# %% [markdown]
# ## Further investigations
#
# 1. Find the time position of the leakage for every key byte.

# %%
plt.figure()
plt.plot(time_pos, list(range(16)), 'x')
plt.xlabel("Time position")
plt.ylabel("Byte position")
plt.title("Time position of every byte")
plt.show()

# %% [markdown]
# ### Determine how many curves are needed to retrieve a key byte, or the whole key.

# %% [markdown]
# 1. Rank the key, knowing the correct one, after `nb_traces`.

# %%
def rank_correct_byte(key, key_byte_index, traces, messages):
    dpa_out = dpa(range(0, 256), messages, traces, lambda m, g: sel0(m, g, key_byte_index))
    # find the max of each line (256 lines), sort the result and get the sort index
    ranks = np.argsort(np.max(dpa_out, axis=1))[::-1]
    assert len(ranks) == 256
    # print(ranks)
    rank_key_byte = np.where(ranks==key[key_byte_index])
    assert len(rank_key_byte[0]) == 1
    # print(rank_key_byte, key[key_byte_index])
    # print(ranks[rank_key_byte[0][0]])
    
    return rank_key_byte[0][0]

# number of keys that have a higher probability than k
# return an array
def rank_correct(key, nb_traces, traces, messages):
    rank = 0
    for key_byte_index in range(16):
        rank += rank_correct_byte(key, key_byte_index, traces, messages)

    return rank / 16


# test with random key and not enough traces
key = np.random.randint(low=0, high=256, size=16, dtype=np.uint8) 
rank = rank_correct(key, 20, traces[:20,:], messages[:20,:])
print(f"Key : {key}, Rank : {rank}")

# test with the correct key and all available traces
key = bytearray(key_list)
rank = rank_correct(key, 2000, traces, messages)
assert rank == 0
print(f"Key : {key.hex()}, Rank : {rank}")
# Out:
# Key : [ 43 248  77 132 130 248 128 137 111 168  78  48 248 185  55  77], Rank : 99.375
# Key : c15ec015dec0ded0cafedeadbeef00ff, Rank : 0.0

# %% [markdown]
# 2. Calculate the minimum number of traces to find the first byte of the key

# %%
# Test traces concatenation
print(traces.shape)
traces = np.concatenate([traces, traces], axis=0)
print(traces.shape)
# Out:
# (2000, 3500)
# (4000, 3500)

# %%
key = bytearray(key_list)

pl = []
mi, ma, step = 2, 600, 20
for i in tqdm.tnrange(mi, ma, step, desc = "Capturing"):
    pl.append(rank_correct_byte(key, 0, traces[:i,:], messages[:i,:]))

print(pl)
# Out:
# <ipython-input-37-b7e16495c8e8>:5: TqdmDeprecationWarning: Please use `tqdm.notebook.trange` instead of `tqdm.tnrange`
#   for i in tqdm.tnrange(mi, ma, step, desc = "Capturing"):
# Capturing:   0%|          | 0/30 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-37-b7e16495c8e8> in <module>
#       4 mi, ma, step = 1, 600, 20
#       5 for i in tqdm.tnrange(mi, ma, step, desc = "Capturing"):
# ----> 6     pl.append(rank_correct_byte(key, 0, traces[:i,:], messages[:i,:]))
#       7
#       8 print(pl)
#
# <ipython-input-27-2a2b5eecd16d> in rank_correct_byte(key, key_byte_index, traces, messages)
#       1 def rank_correct_byte(key, key_byte_index, traces, messages):
# ----> 2     dpa_out = dpa(range(0, 256), messages, traces, lambda m, g: sel0(m, g, key_byte_index))
#       3     # find the max of each line (256 lines), sort the result and get the sort index
#       4     ranks = np.argsort(np.max(dpa_out, axis=1))[::-1]
#       5     assert len(ranks) == 256
#
# <ipython-input-21-bf4a91d64061> in dpa(guesses, messages, traces, selection_function)
#       3
#       4     for index, key_guess in enumerate(guesses):
# ----> 5         matrix[index] = hypothesis(key_guess, messages, traces, selection_function)
#       6
#       7     return matrix  # matrix of 256 hypothesis vectors
#
# <ipython-input-36-dfeffca02918> in hypothesis(guess, messages, traces, selection_function)
#      22             h_0_count += 1
#      23
# ---> 24     assert h_0_count != 0 and h_1_count != 0
#      25
#      26     # return the difference of the two sets ie. abs(mean(h_0) - mean(h_1))
#
# AssertionError:

# %% [markdown]
# 3. Plot the correct key rank with an increasing number of traces.

# %%
pl = []
mi, ma, step = 1, 1000, 50
key = bytearray(key_list)
for i in tnrange(mi, ma, step, desc = "Capturing"):
    pl.append(rank_correct(key, i, traces[:i,:], messages[:i,:]))

print(pl)

plt.figure()
plt.plot(range(mi, ma, step), pl)
plt.xlabel("Nb_curves")
plt.ylabel("Correct key rank")
plt.grid()
plt.show()
# We have the good rank at 800 curves
# Out:
# /home/vagrant/.pyenv/versions/3.6.7/envs/cw/lib/python3.6/site-packages/ipykernel_launcher.py:4: TqdmDeprecationWarning: Please use `tqdm.notebook.trange` instead of `tqdm.tnrange`
#   after removing the cwd from sys.path.
# HBox(children=(FloatProgress(value=0.0, description='Capturing', max=20.0, style=ProgressStyle(description_wid…
# /home/vagrant/.pyenv/versions/3.6.7/envs/cw/lib/python3.6/site-packages/ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in true_divide
# [109.75, 141.0625, 121.3125, 89.6875, 87.375, 70.1875, 51.6875, 35.75, 24.0, 18.25, 16.8125, 9.4375, 7.25, 3.8125, 1.625, 0.375, 0.5625, 0.3125, 0.0625, 0.0]

# %% [markdown]
# 4. Attack another part of the algorithm, for instance the first AddRoundKey

# %%
# To attack the first AddRoundKey change the target function to (msg ^ key)[byte_i]
